# %%
from __future__ import print_function
import numpy as np
import os
import shutil
import glob
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
tab1 = pd.read_table('../Table1_MAG.txt', header=0, sep='\t')
tab1
# Out:
#              Model Mag.  FOV   Params  Tile F1   WSI F1   Time     FPS
# 0         DenseNet   5x   512   15.87     0.750   0.763  0.430  264.65
# 1         DenseNet  10x   512   15.87     0.767   0.748  1.080  102.83
# 2         DenseNet  20x   512   15.87     0.719   0.636  3.040   36.11
# 3              FCN   5x   512   39.41     0.712   0.775  0.740  202.60
# 4              FCN  10x   512   39.41     0.738   0.745  1.550   93.70
# 5              FCN  20x   512   39.41     0.748   0.676  7.460   18.90
# 6            U-Net   5x   512   31.03     0.771   0.806  0.861  171.88
# 7            U-Net  10x   512   31.03     0.803   0.797  2.160   66.54
# 8            U-Net  20x   512   31.03     0.673   0.429  7.910   18.04
# 9   DenseNet-Small   5x   512    4.39     0.749   0.794  0.780  191.80
# 10  DenseNet-Small  10x   512    4.39     0.805   0.845  1.560   93.70
# 11  DenseNet-Small  20x   512    4.39     0.726   0.649  2.850   49.90
# ...

# %%
tab2 = pd.read_table('../Table2_FOV.txt', header=0, sep='\t')
tab2
# Out:
#              Model Mag.  FOV   Params  Tile F1   WSI F1   Time     FPS
# 0         DenseNet   5x  1024   15.87     0.771   0.687  0.235  121.79
# 1         DenseNet  10x   512   15.87     0.777   0.749  1.080  103.20
# 2         DenseNet  20x   256   15.87     0.826   0.592  3.250  136.84
# 3              FCN   5x  1024   39.41     0.765   0.828  0.330  117.40
# 4              FCN  10x   512   39.41     0.760   0.782  1.520   95.70
# 5              FCN  20x   256   39.41     0.770   0.613  4.170  137.12
# 6            U-Net   5x  1024   31.03     0.777   0.757  0.572   64.54
# 7            U-Net  10x   512   31.03     0.706   0.633  2.150   66.86
# 8            U-Net  20x   256   31.03     0.741   0.527  7.923   72.68
# 9   DenseNet-Small   5x  1024    4.39     0.784   0.808  0.310  126.80
# 10  DenseNet-Small  10x   512    4.39     0.804   0.845  1.530   95.30
# 11  DenseNet-Small  20x   256    4.39     0.852   0.753  4.080  140.70
# ...

# %%
sns.regplot(tab1.iloc[:, 4], tab.iloc[:, 5])
# sns.regplot(tab2.iloc[:, 4], tab.iloc[:, 5])

# %%
sns.regplot(tab1.iloc[:,5], tab1.iloc[:,6])
