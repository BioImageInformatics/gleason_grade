# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table('../speed_profile_wsi.txt', sep='\t', header=0, index_col=None)
# Out:
#                 MODEL                                              SLIDE  MAG  \
# 0            DenseNet                               /dev/shm/1304715.svs    5
# 1            DenseNet                               /dev/shm/1304715.svs    5
# 2            DenseNet                               /dev/shm/1304715.svs   10
# 3            DenseNet                               /dev/shm/1304715.svs   20
# 4                UNet                               /dev/shm/1304715.svs    5
# 5                UNet                               /dev/shm/1304715.svs    5
# 6                UNet                               /dev/shm/1304715.svs   10
# 7                UNet                               /dev/shm/1304715.svs   20
# 8                 FCN                               /dev/shm/1304715.svs    5
# 9                 FCN                               /dev/shm/1304715.svs    5
# 10                FCN                               /dev/shm/1304715.svs   10
# ...

# %%
df_ = df.iloc[[x==5 for x in df.MAG], :]
df_.sort_values(['PROC_SIZE', 'FPS'], ascending=[True, False])
# Out:
#                 MODEL                                              SLIDE  MAG  \
# 32  MobileNet-v2-035%                               /dev/shm/1304715.svs    5
# 34  MobileNet-v2-050%                               /dev/shm/1304715.svs    5
# 36  MobileNet-v2-100%                               /dev/shm/1304715.svs    5
# 24             UNet-S                               /dev/shm/1304715.svs    5
# 12         DenseNet-S                               /dev/shm/1304715.svs    5
# 8                 FCN                               /dev/shm/1304715.svs    5
# 0            DenseNet                               /dev/shm/1304715.svs    5
# 4                UNet                               /dev/shm/1304715.svs    5
# 45         Densenet-S  /dev/shm/TCGA-2A-A8VL-01Z-00-DX1.2C2BD6EF-EC17...    5
# 38  MobileNet-v2-035%                               /dev/shm/1304715.svs    5
# 40  MobileNet-v2-050%                               /dev/shm/1304715.svs    5
# ...

# %%
df_ = df.iloc[[x==10 for x in df.MAG], :]
df_.sort_values(['PROC_SIZE', 'FPS'], ascending=[True, False])
# Out:
#                 MODEL                                              SLIDE  MAG  \
# 37  MobileNet-v2-100%                               /dev/shm/1304715.svs   10
# 33  MobileNet-v2-035%                               /dev/shm/1304715.svs   10
# 35  MobileNet-v2-050%                               /dev/shm/1304715.svs   10
# 39  MobileNet-v2-035%                               /dev/shm/1304715.svs   10
# 43  MobileNet-v2-100%                               /dev/shm/1304715.svs   10
# 41  MobileNet-v2-050%                               /dev/shm/1304715.svs   10
# 44         Densenet-S  /dev/shm/TCGA-2A-A8VL-01Z-00-DX1.2C2BD6EF-EC17...   10
# 22         DenseNet-S                               /dev/shm/1304715.svs   10
# 26             UNet-S                               /dev/shm/1304715.svs   10
# 10                FCN                               /dev/shm/1304715.svs   10
# 2            DenseNet                               /dev/shm/1304715.svs   10
# ...

# %%
df_ = df.iloc[[x==20 for x in df.MAG], :]
df_.sort_values(['PROC_SIZE', 'FPS'], ascending=[True, False])
# Out:
#                 MODEL                                              SLIDE  MAG  \
# 48  MobileNet-v2-050%                               /dev/shm/1304715.svs   20
# 47  MobileNet-v2-035%                               /dev/shm/1304715.svs   20
# 27             UNet-S                               /dev/shm/1304715.svs   20
# 23         DenseNet-S                               /dev/shm/1304715.svs   20
# 3            DenseNet                               /dev/shm/1304715.svs   20
# 46         Densenet-S  /dev/shm/TCGA-2A-A8VL-01Z-00-DX1.2C2BD6EF-EC17...   20
# 11                FCN                               /dev/shm/1304715.svs   20
# 7                UNet                               /dev/shm/1304715.svs   20
#
#     PROC_SIZE  BATCH  N_TILES  TOTAL_SECONDS         FPS
# 48        128     32   148052     543.846980  272.230987
# 47        128     32   148052     547.796641  270.268178
# 27        512      2     9173     181.344301   50.583338
# ...
